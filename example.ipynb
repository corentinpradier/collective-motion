# %% [markdown]
# <h1 style="text-align:center; font-weight:bold"> Murmuration - exemples d'utilisation </h1>

# %% [markdown]
# # 1 - Premiers tests

# %%
from functions_v2 import main, plot_run
from validation import plot_msd_po, corr_diff

# %%
# Paramètres initiaux
Nt = 100  # Nombre de frames
v = 1  # Vitesse des oiseaux
dt = 0.8  # Pas de temps
Dr = 0.8  # Coefficient de diffusion
R0 = 5  # Rayon autour des oiseaux
L = 30  # Dimensions de la boîte
Coeff_couple = 0.8  # Coeficient de couplage
N_birds = 200  # Nombre d'oiseaux
l0 = 1

# %%
position, angle, tab_param_ordre = main(Nt, N_birds, L, Coeff_couple, R0, Dr, v, dt, l0)
plot_run(Nt, N_birds, L, position, angle)

# %%
plot_msd_po(position, Nt, dt, tab_param_ordre)
# Out:
# 35.8211361469205

# %%
corr_diff(position, angle, N_birds, dt, R0)
# Out:
# /Users/corentinpradier/Documents/Codes/murmuration/validation.py:100: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(

# %% [markdown]
# # 2 -

# %%
from murmuration import Murmuration

# %%
mm = Murmuration(
    time_tot=100,
    n_preys=200,
    n_predators=0,
    diffusion=0.8,
    couplage=0.9,
    radius_predators=10,
    radius_avoid=2,
    radius_influence=5,
    window_width=30,
    time_step=0.8,
)
# Out:
# Il n'y a pas de prédateurs :)

# %%
position, angle = mm.main()
mm.plot_run(position, angle)
